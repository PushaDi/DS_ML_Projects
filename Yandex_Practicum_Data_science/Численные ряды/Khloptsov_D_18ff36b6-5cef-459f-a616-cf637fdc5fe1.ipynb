# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## План работы

# %% [markdown]
# Для успешного выполнения поставленной задачи необходимо:
# - загрузить и исследовать данные:
#   - проанализировать пропуски и обработать их (заполнить или удалить)
#   - исследовать выбросы и аномальные значения
#   - оценить релевантность присутствующих признаков, удалить признаки, которые не являются информативными
# - подготовить выборки для обучения и тестирования моделей
# - подобрать наилучшую модель машинного обучения:
#   - исследовать модели градиентного бустинга (LightGBM) с различными гиперпараметрами
#   - исследовать регрессионные модели (линейная регрессия, случаный лес) с различными гиперпараметрами
# - проанализировать время обучения рассмотренных моделей, время предсказания и их качество
# - протестировать лучшую модель на тестовой выборке

# %%
# !pip install pandas_profiling
# !pip install category_encoders
# Out:
# Requirement already satisfied: pandas_profiling in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (3.6.6)
# Requirement already satisfied: ydata-profiling in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas_profiling) (4.3.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (6.0)
# Requirement already satisfied: wordcloud>=1.9.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.9.2)
# Requirement already satisfied: requests<3,>=2.24.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (2.28.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.9.1)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (0.12.3)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (0.12.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (4.65.0)
# Requirement already satisfied: imagehash==4.3.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (4.3.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (2.0.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (3.7.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (0.14.0)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (0.1.12)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (3.1.2)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.10.1)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.23.5)
# Requirement already satisfied: dacite>=1.8 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.8.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (1.10.9)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (0.7.5)
# Requirement already satisfied: typeguard<3,>=2.13.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from ydata-profiling->pandas_profiling) (2.13.3)
# Requirement already satisfied: PyWavelets in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (1.4.1)
# Requirement already satisfied: pillow in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas_profiling) (9.5.0)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (0.2.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas_profiling) (3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas_profiling) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (3.1.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (4.40.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas_profiling) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas_profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas_profiling) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pydantic<2,>=1.8.1->ydata-profiling->pandas_profiling) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas_profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (0.5.3)
# Requirement already satisfied: zipp>=3.1.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.2->ydata-profiling->pandas_profiling) (3.11.0)
# Requirement already satisfied: six in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling->pandas_profiling) (1.16.0)
# Requirement already satisfied: category_encoders in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (2.6.1)
# Requirement already satisfied: pandas>=1.0.5 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: scipy>=1.0.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (1.23.5)
# Requirement already satisfied: statsmodels>=0.9.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from category_encoders) (0.14.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas>=1.0.5->category_encoders) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from pandas>=1.0.5->category_encoders) (2022.7)
# Requirement already satisfied: six in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.3.1)
# Requirement already satisfied: packaging>=21.3 in /Users/dmitry/opt/anaconda3/envs/ds_practicum_env/lib/python3.9/site-packages (from statsmodels>=0.9.0->category_encoders) (22.0)

# %%
import os
import math
import pandas as pd
from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from category_encoders.leave_one_out import LeaveOneOutEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Загрузим исходный датасет и исследуем его.

# %%
local_path = 'autos.csv'
server_path = '/datasets/autos.csv'

if os.path.exists(local_path):
    data = pd.read_csv(local_path)
else:
    data = pd.read_csv(server_path)

# %%
data.head()
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500       small              2001  manual     75
# 4  2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0   golf     150000                  0    petrol  volkswagen      NaN
# 1    NaN     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep      NaN
# 3   golf     150000                  6    petrol  volkswagen       no
# 4  fabia      90000                  7  gasoline       skoda       no
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00                 0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00                 0       60437  2016-04-06 10:17:21

# %% [markdown]
# В представленном датасете имеется информация об автомобилях. Представлены следующие данные:
# - DateCrawled — дата скачивания анкеты из базы
# - VehicleType — тип автомобильного кузова
# - RegistrationYear — год регистрации автомобиля
# - Gearbox — тип коробки передач
# - Power — мощность (л. с.)
# - Model — модель автомобиля
# - Kilometer — пробег (км)
# - RegistrationMonth — месяц регистрации автомобиля
# - FuelType — тип топлива
# - Brand — марка автомобиля
# - Repaired — была машина в ремонте или нет
# - DateCreated — дата создания анкеты
# - NumberOfPictures — количество фотографий автомобиля
# - PostalCode — почтовый индекс владельца анкеты (пользователя)
# - LastSeen — дата последней активности пользователя
# - Price — цена (евро)

# %% [markdown]
# Проанализируем данные на наличие пропусков, дубликатов и аномальных значений.

# %% [markdown]
# ### Удаление дубликатов

# %%
data.duplicated().sum()
# Out:
# 4

# %% [markdown]
# В датасете присутствует 4 дубликата. Удалим их.

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Рассмотрим наличие пропусков в столбцах.

# %%
data.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Kilometer                0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# Repaired             71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %% [markdown]
# Пропуски присутствуют в следующих столбцах:
# - `Vehicle Type` (тип кузова)
# - `Gearbox` (тип коробки передач)
# - `Model` (модель автомобиля)
# - `Fuel Type` (тип топлива)
# - `Repaired` (наличие или отсутствие ремонта)
#
# Рассмотрим каждый столбец отдельно.

# %% [markdown]
# Тип кузова может быть не указан из-за отсутствия нужного выбора в анкете.
# Рассмотрим все имеющиеся значения данного признака.

# %%
data['VehicleType'].unique()
# Out:
# array([nan, 'coupe', 'suv', 'small', 'sedan', 'convertible', 'bus',
#        'wagon', 'other'], dtype=object)

# %% [markdown]
# Как мы видим, в датасете уже присутствуют значения `other`. В таком случае, заполним имеющиеся пропуски тем же значением.

# %%
data['VehicleType'].fillna(value='other', inplace=True)
data['VehicleType'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим столбец `Gearbox`, в котором приводится информация о типе коробки передач.
# Для начала, рассмотрим, какие значения присутствуют в датасете.

# %%
data['Gearbox'].unique()
# Out:
# array(['manual', 'auto', nan], dtype=object)

# %% [markdown]
# В данном случае, заполним отсутствующие значения модой значения той же модели.

# %%
for i, row in data[data['Gearbox'].isna()].iterrows():
    brand = row['Brand']
    model = row['Model']

    mode_value = data[
        data['Model'] == model
    ]['Gearbox'].mode()

    if not mode_value.empty:
        mode_value = mode_value[0]
        if not pd.isna(mode_value):
            data.at[i, 'Gearbox'] = mode_value

# %%
data['Gearbox'].isna().sum() / len(data)
# Out:
# 0.01165747181578316

# %% [markdown]
# По итогам заполнения осталось незаполненными около 1% от всех данных. Удалим эти строки.

# %%
data.dropna(subset=['Gearbox'], inplace=True)
data['Gearbox'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим столбец `Model`, в котором приводится информация о модели автомобиля.
# Для начала, рассмотрим, какие значения присутствуют в датасете.

# %%
data['Model'].unique()
# Out:
# array(['golf', nan, 'grand', 'fabia', '3er', '2_reihe', 'other', 'c_max',
#        '3_reihe', 'passat', 'navara', 'ka', 'polo', 'twingo', 'a_klasse',
#        'scirocco', '5er', 'meriva', 'arosa', 'c4', 'civic', 'transporter',
#        'punto', 'e_klasse', 'clio', 'kadett', 'kangoo', 'corsa', 'one',
#        'fortwo', '1er', 'b_klasse', 'signum', 'astra', 'a8', 'jetta',
#        'fiesta', 'c_klasse', 'micra', 'vito', 'sprinter', '156', 'escort',
#        'forester', 'xc_reihe', 'scenic', 'a4', 'a1', 'insignia', 'combo',
#        'focus', 'tt', 'a6', 'jazz', 'omega', 'slk', '7er', '80', '147',
#        '100', 'z_reihe', 'sportage', 'sorento', 'v40', 'ibiza', 'mustang',
#        'eos', 'touran', 'getz', 'a3', 'almera', 'megane', 'lupo', 'r19',
#        'zafira', 'caddy', 'mondeo', 'cordoba', 'colt', 'impreza',
#        'vectra', 'berlingo', 'tiguan', 'i_reihe', 'espace', 'sharan',
#        '6_reihe', 'panda', 'up', 'seicento', 'ceed', '5_reihe', 'yeti',
#        'octavia', 'mii', 'rx_reihe', '6er', 'modus', 'fox', 'matiz',
#        'beetle', 'c1', 'rio', 'touareg', 'logan', 'spider', 'cuore',
#        's_max', 'a2', 'galaxy', 'c3', 'viano', 's_klasse', '1_reihe',
#        'avensis', 'roomster', 'sl', 'kaefer', 'santa', 'cooper', 'leon',
#        '4_reihe', 'a5', '500', 'laguna', 'ptcruiser', 'clk', 'primera',
#        'x_reihe', 'exeo', '159', 'transit', 'juke', 'qashqai', 'carisma',
#        'accord', 'corolla', 'lanos', 'phaeton', 'verso', 'swift', 'rav',
#        'picanto', 'boxster', 'kalos', 'superb', 'stilo', 'alhambra',
#        'mx_reihe', 'roadster', 'ypsilon', 'cayenne', 'galant', 'justy',
#        '90', 'sirion', 'crossfire', 'agila', 'duster', 'cr_reihe', 'v50',
#        'c_reihe', 'v_klasse', 'm_klasse', 'yaris', 'c5', 'aygo', 'cc',
#        'carnival', 'fusion', '911', 'bora', 'forfour', 'm_reihe', 'cl',
#        'tigra', '300c', 'spark', 'v70', 'kuga', 'x_type', 'ducato',
#        's_type', 'x_trail', 'toledo', 'altea', 'voyager', 'calibra',
#        'bravo', 'antara', 'tucson', 'citigo', 'jimny', 'wrangler',
#        'lybra', 'q7', 'lancer', 'captiva', 'c2', 'discovery',
#        'freelander', 'sandero', 'note', '900', 'cherokee', 'clubman',
#        'samara', 'defender', '601', 'cx_reihe', 'legacy', 'pajero',
#        'auris', 'niva', 's60', 'nubira', 'vivaro', 'g_klasse', 'lodgy',
#        '850', 'range_rover', 'q3', 'serie_2', 'glk', 'charade', 'croma',
#        'outlander', 'doblo', 'musa', 'move', '9000', 'v60', '145', 'aveo',
#        '200', 'b_max', 'range_rover_sport', 'terios', 'rangerover', 'q5',
#        'range_rover_evoque', 'materia', 'delta', 'gl', 'kalina', 'amarok',
#        'elefantino', 'i3', 'kappa', 'serie_3', 'serie_1'], dtype=object)

# %% [markdown]
# Как мы видим, в списке всех возможных моделей присутствует вариант `other`. В связи со сложностью заполнения данного столбца, заполним все пропуски данным вариантом.

# %%
data['Model'].fillna(value='other', inplace=True)
data['Model'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим значения признака `FuelType`, описывающего вид используемого топлива.

# %%
data['FuelType'].unique()
# Out:
# array(['petrol', 'gasoline', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electric'], dtype=object)

# %% [markdown]
# По аналогии с предыдущим признаком, так же заполним его с помощью значения `other`.

# %%
data['FuelType'].fillna(value='other', inplace=True)
data['FuelType'].isna().sum()
# Out:
# 0

# %% [markdown]
# Обработаем пропуски в столбце `Repaired`.

# %%
data['Repaired'].unique()
# Out:
# array([nan, 'yes', 'no'], dtype=object)

# %% [markdown]
# Скорее всего, наличие пропусков в данном столбце говорит об отсутствии ремонта у автомобиля.
# Следовательно, заполним пропущенные значения отрицательным ответом.

# %%
data['Repaired'].fillna(value='no', inplace=True)
data['Repaired'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# Среди численных признаков, где возможны выбросы и аномальные значения имеются:
# - RegistrationYear — год регистрации автомобиля
# - Power — мощность (л. с.)
# - Kilometer — пробег (км)
# - RegistrationMonth — месяц регистрации автомобиля
# - NumberOfPictures — количество фотографий автомобиля
# - Price — цена (евро)

# %% [markdown]
# Рассмотрим распределение значений перечисленных признаков.

# %%
numerical_features = [
    'RegistrationYear', 'Power', 'Kilometer', 'RegistrationMonth', 'NumberOfPictures', 'Price'
]

for feature in numerical_features:
    print('-' * 22)
    print(feature)
    print('-' * 22)
    print(data[feature].describe())
# Out:
# ----------------------
# RegistrationYear
# ----------------------
# count    350234.000000
# mean       2003.856188
# std          68.795645
# min        1000.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2008.000000
# max        9999.000000
# Name: RegistrationYear, dtype: float64
# ----------------------
# Power
# ----------------------
# count    350234.000000
# mean        111.046977
# std         189.820035
# min           0.000000
# 25%          69.000000
# 50%         105.000000
# 75%         143.000000
# max       20000.000000
# Name: Power, dtype: float64
# ----------------------
# Kilometer
# ----------------------
# count    350234.000000
# mean     128511.395239
# std       37436.819078
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: Kilometer, dtype: float64
# ----------------------
# RegistrationMonth
# ----------------------
# count    350234.000000
# mean          5.762716
# std           3.705696
# min           0.000000
# 25%           3.000000
# 50%           6.000000
# 75%           9.000000
# max          12.000000
# Name: RegistrationMonth, dtype: float64
# ----------------------
# NumberOfPictures
# ----------------------
# count    350234.0
# mean          0.0
# std           0.0
# min           0.0
# 25%           0.0
# 50%           0.0
# 75%           0.0
# max           0.0
# Name: NumberOfPictures, dtype: float64
# ----------------------
# Price
# ----------------------
# count    350234.000000
# mean       4450.581326
# std        4519.107284
# min           0.000000
# 25%        1100.000000
# 50%        2777.000000
# 75%        6490.000000
# max       20000.000000
# Name: Price, dtype: float64

# %% [markdown]
# В столбце с информацией о годе регистрации автомобиля.
# Для начала, рассмотрим, сколько строк имеет годом регистрации значения, больше чем нынешний год.

# %%
data[(data['RegistrationYear'] > 2023)]['RegistrationYear'].count()
# Out:
# 68

# %%
data[data['RegistrationYear'] > 2023]['RegistrationYear'].value_counts()
# Out:
# RegistrationYear
# 5000    14
# 9999    14
# 3000     5
# 7000     3
# 4000     3
# 6000     3
# 9000     2
# 2500     2
# 8000     2
# 5911     2
# 5555     2
# 7100     1
# 8200     1
# 7800     1
# 7500     1
# 4500     1
# 2800     1
# 3700     1
# 2290     1
# 6500     1
# 4800     1
# 8500     1
# 5900     1
# 2900     1
# 2066     1
# 2200     1
# 3500     1
# Name: count, dtype: int64

# %% [markdown]
# Видно, что данные годы нет возможности логично заменить. При этом их количество мало относительно общего количества данных. В связи с этим данные строки могут быть удалены.

# %%
data = data[data['RegistrationYear'] <= 2023]

# %% [markdown]
# Теперь рассмотрим наименьший год регистрации.
# Самый старый автомобиль, когда-либо проданный, был выпущен в 1884 году. Рассмотрим распределение значений года регистрации, ограничив гистограмму этим значением.

# %%
plt.hist(data['RegistrationYear'], bins=100)
plt.xlim(xmin=1884)
plt.title('Год регистрации')
plt.show()

# %% [markdown]
# Как мы видим, лишь единичные значения попадают в диапазон менее 1960 года.
# Посмотрим на их количество.

# %%
data[data['RegistrationYear'] < 1960]['RegistrationYear'].count()
# Out:
# 313

# %% [markdown]
# Таких значений всего 313. Удалим их.

# %%
data=data[data['RegistrationYear'] >= 1960]

# %% [markdown]
# В столбце с информацией о мощности двигателя так же имеется много выбросов. Присутствует много значений, близких к нулю, а так же превышающих максимально возможную мощность автомобиля.
# Согласно информации из интернета, самым мощным автомобилем является автомобиль с 4515 л.с.
# Автомобиль с наименьшей мощностью - 4.2 л.с.
#
# Подсчитаем количество автомобилей с большей и меньшей мощностью.

# %%
data[(data['Power'] < 4.2) | (data['Power'] > 4515)]['Power'].count()
# Out:
# 37012

# %% [markdown]
# Таких строк более 37 тысяч, что составляет 10% от общего количества строк.
# Скорее всего, данные значения появились из-за ошибки при вводе данных в анкете.
# Рассмотрим отношение стоимости автомобилей к их мощности.

# %%
plt.plot(data['Power'], data['Price'], 'bo')
plt.show()

# %% [markdown]
# Как видно из графика, автомобили мощностью выше 1000 л.с. не имеют самую большую стоимость.
# В связи с этим, можно точно говорить об ошибке, а не о продаже самых мощных автомобилей.
# Поэтому, все значения в диапазоне от 1000 до 10000 следует разделить на 10, а от 10000 - на 100.

# %%
data['Power'].isna().sum()
# Out:
# 0

# %%
def power_correction(power):
    if power < 1000:
        return power
    elif power > 1000 and power < 10000:
        return power / 10
    else:
        return power / 100

data['Power'] = data['Power'].apply(power_correction)

# %%
data['Power'].isna().sum()
# Out:
# 0

# %% [markdown]
# Рассмотрим распределение значений данного столбца еще раз.

# %%
data['Power'].describe()
# Out:
# count    349853.000000
# mean        107.748279
# std          63.934705
# min           0.000000
# 25%          69.000000
# 50%         105.000000
# 75%         143.000000
# max         999.000000
# Name: Power, dtype: float64

# %% [markdown]
# В столбце остались значения равные нулю. Подсчитаем их количество.

# %%
data[data['Power'] == 0]['Power'].count()
# Out:
# 36852

# %% [markdown]
# Таких значений более 10%. Рассмотрим распределение цены для этих значений.

# %%
sns.histplot(data[data['Power'] == 0]['Price'], bins=30, stat='probability')
sns.histplot(data[data['Power'] != 0]['Price'], bins=30, stat='probability')
plt.show()

# %% [markdown]
# Как мы видим, разброс значений в цене для автомобилей с указанной мощностью 0 л.с. слишком большой и схож с общим распределением цены. Значит, это не значения, близкие к нулю, а просто не указанная мощность.
# Поэтому, заполним данные строки значениями моды, как ранее в случае с категориальными признаками.

# %%
data['Power'].isna().sum()
# Out:
# 0

# %%
for i, row in data[data['Power'] == 0].iterrows():
            model = row['Model']
            median_value = data[
                data['Model'] == model
            ]['Power'].median()
            if np.isnan(median_value):
                print('Nan')
            if not np.isnan(median_value):
                data.at[i, 'Power'] = median_value

# %%
data['Power'].isna().sum()
# Out:
# 0

# %%
data[data['Power'] == 0]['Power'].count() / len(data)
# Out:
# 2.858343361354626e-05

# %% [markdown]
# Около 2% значений осталось 0, для них не удалось подсчитать моду. Удалим эти данные

# %%
data.drop(data[data['Power'] == 0].index, inplace=True)

# %% [markdown]
# Месяц регистрации не является релевантным, поскольку при оценке автомобиля используется год выпуска, поэтому обрабатывать аномальные значения в этом столбце не нужно, он будет удален.

# %% [markdown]
# Рассмотрим распределение значений в столбце с ценами.

# %%
data['Price'].describe()
# Out:
# count    349843.000000
# mean       4449.133140
# std        4516.780801
# min           0.000000
# 25%        1100.000000
# 50%        2759.000000
# 75%        6490.000000
# max       20000.000000
# Name: Price, dtype: float64

# %% [markdown]
# Максимальная цена выглядит правдоподобно, как и 1 и 3 квартили.
# рассмотрим гистограмму распределения значений от 0 до 1го квартиля.

# %%
sns.histplot(data[(data['Price'] < 1100)]['Price'], bins=30)
plt.show()

# %% [markdown]
# Как мы видим, присутствует большое количество 0 значений.

# %%
data[data['Price'] == 0]['Price'].count() / len(data)
# Out:
# 0.027666696203725673

# %% [markdown]
# Относительно общего количества строк, нулевая цена имеется в 2 процентах случаев. В связи с этим, выглядит разумным удалить эти строки.

# %%
data = data[data['Price'] > 0]

# %% [markdown]
# ### Удаление нерелевантных признаков

# %% [markdown]
# Как уже говорилось выше, месяц регистрации не является релевантным. Кроме того, нерелевантными признаками для предсказания цены являются:
# - DateCrawled — дата скачивания анкеты из базы
# - DateCreated — дата создания анкеты
# - PostalCode — почтовый индекс владельца анкеты (пользователя)
# - LastSeen — дата последней активности пользователя
#
# Так же, стоит отметить, что из-за того, что у всех объявлений отсутствуют фотографии, данный признак так же не является релевантным.
# Кроме того, можно удалить столбец с маркой автомобиля, поскольку название модели уже вмещает в себя марку.
#
# В связи этим, удалим эти столбцы из датасета.

# %%
data = data.drop(
    ['RegistrationMonth', 'DateCrawled', 'DateCreated', 'PostalCode', 'LastSeen', 'NumberOfPictures', 'Brand'], 
    axis=1
)

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Подготовка выборок

# %% [markdown]
# Для начала отделим целевой признак от остальных.

# %%
target = data['Price']
features = data.drop('Price', axis = 1)

# %% [markdown]
# Разделим выборки на тренировочную и тестовую. Подбор гиперпараметров будет осуществялться методом кросс-валидации, поэтому валидационная выборка не понадобится.

# %%
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=12345
)

# %% [markdown]
# Смасштабируем количественные признаки для улучшения качества модели.

# %%
numeric_features=['RegistrationYear', 'Power', 'Kilometer']

scaler = StandardScaler()
scaler.fit(features_train[numeric_features])

numeric_train_scaled = scaler.transform(features_train[numeric_features])
numeric_test_scaled = scaler.transform(features_test[numeric_features])

features_train[numeric_features] = numeric_train_scaled
features_test[numeric_features] = numeric_test_scaled

# %% [markdown]
# Для обучения классических моделей необходимо закодировать категориальные признаки.
# Для признака `Model` OHE  создаст большое количество новых столбцов, что сильно увеличит размер матрицы.
# В связи с этим, восопльзуемся методом Leave-one-out Encoder. Несмотря на то, что в данном методе кодирование осуществляется с помощью целевого признака, отбрасывание части выборки при обучении данного кодирования позволяет избежать утечки данных.
# Остальные признаки закодируем, воспользовавшись OHE.

# %%
encoder = LeaveOneOutEncoder(cols='Model')
encoder.fit(features_train, target_train)

features_train_encoded = encoder.transform(features_train)
features_test_encoded= encoder.transform(features_test)

# %%
features_train_encoded = pd.get_dummies(features_train_encoded, drop_first=True, dtype='int')
features_test_encoded = pd.get_dummies(features_test_encoded, drop_first=True, dtype='int')

# %% [markdown]
# ### Модель случайного леса

# %% [markdown]
# Обучим модель случайного леса и методом кросс-валидации подберем оптимальные гиперпараметры.

# %%
random_forest_model = RandomForestRegressor(n_jobs=-1, random_state=12345)

random_forest_params = {
    'n_estimators' : range(100, 1000, 100),
    'max_depth' : range(2, 10, 2),
    'min_samples_split' : range(2, 10, 2),
    'min_samples_leaf' : range(2, 100, 10)
}

search_forest_cv = RandomizedSearchCV(
    random_forest_model,
    random_forest_params,
    n_iter=25,
    scoring='neg_mean_squared_error',
    n_jobs=-1
)

# %%
random_forest_search = search_forest_cv.fit(
    features_train_encoded,
    target_train
)

print(f'Лучший результат модели случайного леса: \n{math.sqrt(abs(random_forest_search.best_score_))}')
# Out:
# Лучший результат модели случайного леса:
# 2032.1877363855317

# %% [markdown]
# Лушчая модель случайного леса, подобранная с помощью Randomized Search дала результат метрики RMSE ниже, чем пороговое значение.

# %%
random_forest_model = random_forest_search.best_estimator_

# %% [markdown]
# ### Модель Light GBM

# %% [markdown]
# Для модели градиентного бустинга LightGBM кодирование категориальных признаков не нужно. Поэтому, в данном случае мы воспользуемся оригинальными значениями из датасета.

# %%
categorical_columns = ['VehicleType', 'Gearbox', 'Model', 'FuelType', 'Repaired']
for col in categorical_columns:
    features_train[col] = features_train[col].astype('category')
    features_test[col] = features_test[col].astype('category')

# %%
lgb_params = {
    'num_leaves' : range(10,100,10),
    'max_depth' : range(7,15,1),
    'n_estimators' : range(100,1000,100),
}

lgb_model = lgb.LGBMRegressor(
    objective='regression',
    random_state=12345
)

search_lgb_cv = RandomizedSearchCV(
    lgb_model,
    lgb_params,
    n_iter=25,
    scoring='neg_mean_squared_error',
    n_jobs=-1
)

# %%
search_lgb_cv.fit(features_train, target_train)

print(f'Лучший результат модели Light GBM: \n{math.sqrt(abs(search_lgb_cv.best_score_))}')
# Out:
# Лучший результат модели Light GBM:
# 1622.8055024978373

# %% [markdown]
# Результат Light GBM гораздо лучше, чем у модели случайного леса.

# %%
lgb_model = search_lgb_cv.best_estimator_

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# Сравним время обучения и предсказания двух моделей, а так же их результат на тестовой выборке.

# %%
# %%time

random_forest_model.fit(features_train_encoded, target_train)
# Out:
# CPU times: user 1min 38s, sys: 596 ms, total: 1min 39s
# Wall time: 14.2 s
# RandomForestRegressor(max_depth=8, min_samples_leaf=2, min_samples_split=8,
#                       n_estimators=400, n_jobs=-1, random_state=12345)

# %%
# %%time

random_forest_predictions = random_forest_model.predict(features_test_encoded)
# Out:
# CPU times: user 1.91 s, sys: 61.8 ms, total: 1.97 s
# Wall time: 298 ms

# %%
rmse_forest = mean_squared_error(
    target_test,
    random_forest_predictions,
    squared=False
)
print(f'Результат модели случайного леса на тестовой выборке: {rmse_forest}')
# Out:
# Результат модели случайного леса на тестовой выборке: 2035.2265500463582

# %%
# %%time

lgb_model.fit(features_train, target_train)
# Out:
# CPU times: user 36.9 s, sys: 17.7 s, total: 54.6 s
# Wall time: 13.1 s
# LGBMRegressor(max_depth=9, n_estimators=600, num_leaves=80,
#               objective='regression', random_state=12345)

# %%
# %%time

lgb_model_predictions = lgb_model.predict(features_test)
# Out:
# CPU times: user 3.44 s, sys: 36.7 ms, total: 3.47 s
# Wall time: 464 ms

# %%
rmse_lgb = mean_squared_error(
    target_test,
    lgb_model_predictions,
    squared=False
)
print(f'Результат модели light GBM на тестовой выборке: {rmse_lgb}')
# Out:
# Результат модели light GBM на тестовой выборке: 1601.8314202321044

# %% [markdown]
# Таким образом, несмотря на то, что модель Light GBM предсказывает на несколько милисекунд дольше, она дает гораздо более точный результат, а обучается быстрее. Кроме того, нет необходимости обрабатывать категориальные признаки, которых большое количество.

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнена загрузка и подготовка данных
# - [x]  Выполнено обучение моделей
# - [x]  Есть анализ скорости работы и качества моделей
