# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Дмитрий, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам аналитика. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
# Я не смогу принять проект, если в нём будет хотя бы одна критичная ошибка или несколько некритичных ошибок - тогда проект нужно будет немного доработать. Но это нестрашно - я обязательно дам тебе подсказку или укажу верное направление.
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Привет, Алексей! Рад познакомиться и большое спасибо за ревью!
# Постараюсь исправить все с первого раза!
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span><ul class="toc-item"><li><span><a href="#О-проекте" data-toc-modified-id="О-проекте-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>О проекте</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проверка-вычисления-эффективности-обогащения" data-toc-modified-id="Проверка-вычисления-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка вычисления эффективности обогащения</a></span></li><li><span><a href="#Сравнение-тренировочной-и-тестовой-выборок" data-toc-modified-id="Сравнение-тренировочной-и-тестовой-выборок-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Сравнение тренировочной и тестовой выборок</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Выводы-по-этапу" data-toc-modified-id="Выводы-по-этапу-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Выводы по этапу</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-изменения-концентрации-элементов-на-различных-этапах" data-toc-modified-id="Анализ-изменения-концентрации-элементов-на-различных-этапах-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ изменения концентрации элементов на различных этапах</a></span></li><li><span><a href="#Распределение-размеров-гранул-исходного-сырья" data-toc-modified-id="Распределение-размеров-гранул-исходного-сырья-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Распределение размеров гранул исходного сырья</a></span></li><li><span><a href="#Суммарные-концентрации-металлов" data-toc-modified-id="Суммарные-концентрации-металлов-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Суммарные концентрации металлов</a></span></li><li><span><a href="#Выводы-по-этапу" data-toc-modified-id="Выводы-по-этапу-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Выводы по этапу</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Создание-оценочной-метрики" data-toc-modified-id="Создание-оценочной-метрики-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание оценочной метрики</a></span></li><li><span><a href="#Подготовка--данных-для-обучения" data-toc-modified-id="Подготовка--данных-для-обучения-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Подготовка  данных для обучения</a></span></li><li><span><a href="#Выбор-наилучшей-модели" data-toc-modified-id="Выбор-наилучшей-модели-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выбор наилучшей модели</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Введение

# %% [markdown]
# ### О проекте

# %% [markdown]
# ***Описание данных***
#
# **Технологический процесс**:
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Параметры этапов**:
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# **Наименование признаков**
#
# Наименование признаков должно быть такое: `[этап].[тип_параметра].[название_параметра]` *(Пример: rougher.input.feed_ag)*
#
# **Возможные значения для блока [этап]**:
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]**:
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# Для успешного выполнения данного проекта необходимо:
# - изучить исходные данные
# - предобработать данные: проверить на наличие пропусков, дубликатов, аномальных значений
# - исследовать данные: как изменяется концентрация металлов на различных этапах, проанализировать их распределение
# - исследовать суммарную концентрацию металлов на разных стадиях и ее распределение
# - сравнить распределение размеров гранул исходного сырья на обучающей и тестовой выборках
# - провести подготовку признаков: при наличии категориальных признаков - произвести кодирование, смасштабировать количественные признаки
# - изучить работу различных моделей, выбрать с помощью метода кросс-валидации лучшую модель с лучшими гиперпараметрами и рассчитать метрику качества sMAPE - средняя абсолютная ошибка в процентах.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

import sklearn

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка данных

# %%
try:
    data_train = pd.read_csv('initial_data/gold_industry_train.csv')
    data_test = pd.read_csv('initial_data/gold_industry_test.csv')
    data_full = pd.read_csv('initial_data/gold_industry_full.csv')
except:
    data_train = pd.read_csv('/datasets/gold_industry_train.csv')
    data_test = pd.read_csv('/datasets/gold_industry_test.csv')
    data_full = pd.read_csv('/datasets/gold_industry_full.csv')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных задать индекс-столбец- за это действие отвечает параметр `index_col`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# О, спасибо за подсказку! Поскольку, видимо, следующие проекты будут куда требовательнее к мощностям и времени расчета, скорее всего буду тоже делать локально, и использую данный совет!
# </div>

# %% [markdown]
# ### Проверка вычисления эффективности обогащения

# %% [markdown]
# Эффективность обогащения вычисляется по формуле:
#
# $\ Recovery = \frac{C \times (F-T)}{F \times (C-T)} \times 100%$, где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.

# %% [markdown]
# Проверим правильность рассчета эффективности отчистки на этапе флотации. Рассчитаем эффективность по формуле выше и сравним с имеющимися значениями, определив среднюю абсолютную ошибку для получившихся и данных значений.

# %%
def recovery_rate(c, f, t):
    recovery = (c * (f - t)) / (f * (c - t)) * 100
    return recovery

# %%
calculated_recovery = recovery_rate(
    data_train['rougher.output.concentrate_au'], 
    data_train['rougher.input.feed_au'], 
    data_train['rougher.output.tail_au']
)

mean_absolute_error(
    calculated_recovery,
    data_train['rougher.output.recovery']
)
# Out:
# 9.83758577644259e-15

# %% [markdown]
# Средняя абсолютная ошибка стремится к 0, в связи с чем можно сделать вывод о правильности данных в тренировочной выборке.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Оценили `MAE` между исходным и расчётным значением эффективности обогащения и убедились, что эффективность обогащения рассчитана правильно - отлично!
# </div>

# %% [markdown]
# ### Сравнение тренировочной и тестовой выборок

# %% [markdown]
# Сравним тестовую и тренировочную выборки на наличие различий в количестве представленных столбцов.

# %%
print(f'Количество параметров в тестовой выборке: {len(data_test.columns)} \nКоличество параметров в тренировочной выборке: {len(data_train.columns)}')
# Out:
# Количество параметров в тестовой выборке: 53
# Количество параметров в тренировочной выборке: 87

# %% [markdown]
# Как мы видим, в тестовой выборке гораздо меньше параметров. В связи с этим, при обучении модели в будущем, данные отсутствующие параметры учитывать нельзя.

# %% [markdown]
# Рассмотрим, какие из параметров отсутствуют в тестовой выборке, но есть в тренировочной.

# %%
missing_columns = set(data_train) - set(data_test)

missing_columns
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Как мы видим, в тестовой выборке отсутствуют значения параметров продукта после технологических операций, а так же расчетные характеристики после флотации.

# %% [markdown]
# Данное расхождение в количестве данных между обучающей и тестовой выборкой связано с тем, что тестовая выборка приближена к реальной жизни, и в ней имеются только те параметры, которые были получены непосредственно в ходе технологического процесса.
# Отсутствующие параметры были получены уже позже, поэтому они отсутствуют в тестовой выборке, но присутствуют в исходных данных, и в тренировочной выборке.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализировали разницу в признаках между выборками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Здесь стоит вспомнить разницу между онлайн и оффлайн метриками: исходя из понимания, что тестовая выборка имитирует работу модели в реальных условиях протекания технологического процесса, давай подумаем, почему в `train` есть признаки, которые недоступны в `test`?
#
# Нужно сделать вывод о причине расхожедния количества признаков между `train` и `test`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Исправил!
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Рассмотрим и подготовим данные, представленные всех выборках для анализа и дальнейшего обучения модели.

# %%
data_train.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_test.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %%
data_full.head()
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# ...

# %% [markdown]
# Для начала, приведем данные о дате в формат даты и сделаем данный столбец индексом, поскольку все данные индексируются по времени получения информации.

# %%
data_train['date'] = pd.to_datetime(data_train['date'], format='%Y-%m-%d %H:%M:%S')
data_train = data_train.set_index('date')
data_test['date'] = pd.to_datetime(data_test['date'], format='%Y-%m-%d %H:%M:%S')
data_test = data_test.set_index('date')
data_full['date'] = pd.to_datetime(data_full['date'], format='%Y-%m-%d %H:%M:%S')
data_full = data_full.set_index('date')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Дату привели к нужному виду - отлично!

# %% [markdown]
# Проанализируем данные на наличие пропусков.

# %%
data_train.isna().sum()
# Out:
# rougher.input.feed_au                                   0
# rougher.input.feed_ag                                   0
# rougher.input.feed_pb                                  72
# rougher.input.feed_sol                                 77
# rougher.input.feed_rate                                 7
# rougher.input.feed_size                               101
# rougher.input.floatbank10_sulfate                      31
# rougher.input.floatbank10_xanthate                      7
# rougher.state.floatbank10_a_air                         0
# rougher.state.floatbank10_a_level                       0
# rougher.state.floatbank10_b_air                         0
# rougher.state.floatbank10_b_level                       0
# rougher.state.floatbank10_c_air                         0
# rougher.state.floatbank10_c_level                       0
# rougher.state.floatbank10_d_air                         0
# rougher.state.floatbank10_d_level                       0
# ...

# %%
data_test.isna().sum()
# Out:
# rougher.input.feed_au                           0
# rougher.input.feed_ag                           0
# rougher.input.feed_pb                          28
# rougher.input.feed_sol                         22
# rougher.input.feed_rate                         4
# rougher.input.feed_size                        44
# rougher.input.floatbank10_sulfate               3
# rougher.input.floatbank10_xanthate              1
# rougher.state.floatbank10_a_air                 1
# rougher.state.floatbank10_a_level               1
# rougher.state.floatbank10_b_air                 1
# rougher.state.floatbank10_b_level               1
# rougher.state.floatbank10_c_air                 1
# rougher.state.floatbank10_c_level               1
# rougher.state.floatbank10_d_air                 0
# rougher.state.floatbank10_d_level               0
# rougher.state.floatbank10_e_air                 7
# rougher.state.floatbank10_e_level               0
# rougher.state.floatbank10_f_air                 0
# ...

# %%
data_full.isna().sum()
# Out:
# rougher.input.feed_au                                    0
# rougher.input.feed_ag                                    0
# rougher.input.feed_pb                                  100
# rougher.input.feed_sol                                  99
# rougher.input.feed_rate                                 11
# rougher.input.feed_size                                145
# rougher.input.floatbank10_sulfate                       34
# rougher.input.floatbank10_xanthate                       8
# rougher.state.floatbank10_a_air                          1
# rougher.state.floatbank10_a_level                        1
# rougher.state.floatbank10_b_air                          1
# rougher.state.floatbank10_b_level                        1
# rougher.state.floatbank10_c_air                          1
# rougher.state.floatbank10_c_level                        1
# rougher.state.floatbank10_d_air                          0
# rougher.state.floatbank10_d_level                        0
# ...

# %% [markdown]
# Пропусков, относительно общего количества данных, немного, но они есть. Необходимо заполнить их. Поскольку данные индексируются датой и временем получения информации, а соседние по времени параметры похожи, можно заполнить имеющиеся пропуски предыдущим значением.

# %%
for data in data_train, data_test, data_full:
    data.fillna(method='ffill', inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Обработали пропуски с помощью стратегии заполнения `forward fill`, а также пояснили причину выбора такой стратегии - отлично!
# </div>

# %% [markdown]
# Проверим распределение значений в имеющихся параметрах на наличие выбросов и аномальных значений.

# %%
for column in data_full.columns:
    sns.histplot(data_full, x=column)
    plt.show()

# %% [markdown]
# Аномальные выбросы в районе минимальных и/или максимальных значениях имеются в столбцах с параметрами, описывающими:
# - концентрация металлов и солей в исходном сырье
# - расчет отношения концентрации золота к свинцу после флотации
# - концентрацию металлов и солей после флотации
# - коэффициент извлекаемости после флотации
# - концентрация металлов и солей после первичной очистки
# - концентрация металлов и солей в хвостах после первичной очистки
# - концентрация металлов и солей в хвостах после вторичной очистки
# - концентрация металлов итогового продукта и итоговых хвостов
#
# Как видно, все эти параметры относятся к параметрам, связанным с содержанием элементов, а некоторые расчетные и зависят от них. В связи с этим, для исключения влияния данных выбросов на анализ данных и дальнейшее обучение модели можно либо удалить данные значения, либо заменить их с помощью ближайших по времени значений.
# Поскольку количество таких выбросов относительно общих данных мало, удалим данные значения из исходных данных и из тренировочной и тестовой выборки, если они там присутствуют.

# %%
columns_to_clear = [
    'rougher.input.feed_au',
    'rougher.input.feed_ag',
    'rougher.input.feed_pb',
    'rougher.input.feed_sol',
    'rougher.input.feed_rate',
    'rougher.calculation.au_pb_ratio',
    'rougher.output.concentrate_au',
    'rougher.output.concentrate_ag',
    'rougher.output.concentrate_pb',
    'rougher.output.concentrate_sol',
    'rougher.output.recovery',
    'primary_cleaner.output.concentrate_au',
    'primary_cleaner.output.concentrate_ag',
    'primary_cleaner.output.concentrate_pb',
    'primary_cleaner.output.concentrate_sol',
    'primary_cleaner.output.tail_au',
    'primary_cleaner.output.tail_ag',
    'primary_cleaner.output.tail_pb',
    'primary_cleaner.output.tail_sol',
    'secondary_cleaner.output.tail_au',
    'secondary_cleaner.output.tail_ag',
    'secondary_cleaner.output.tail_pb',
    'secondary_cleaner.output.tail_sol',
    'final.output.concentrate_au',
    'final.output.concentrate_ag',
    'final.output.concentrate_pb',
    'final.output.concentrate_sol',
    'final.output.recovery',
    'final.output.tail_au',
    'final.output.tail_ag',
    'final.output.tail_pb',
    'final.output.tail_sol',
]

# %%
for column in columns_to_clear:
    dates_to_delete = (data_full[data_full[column] <= 0.01].index)
    data_full = data_full.drop(dates_to_delete)
    data_train = data_train.drop(dates_to_delete, errors='ignore')
    data_test = data_test.drop(dates_to_delete, errors='ignore')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличная идея с фильтрацией выбросов!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аномалии также присутствуют на этапе `rougher.input.feed_металл`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит сделать промежуточные выводы о проделанной работе в блоке.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %% [markdown]
# ### Выводы по этапу

# %% [markdown]
# В ходе предобработки данных была проверена правильность вычисления эффективности обогащения в тренировочных данных. Сравнение имеющихся с данных с расчетной величиной показало среднюю абсолютную ошибку (MAE), близкую к 0, что позволяет сделать вывод о правильности имеющихся данных.
#
# Для удобства, данные в столбце `date` были приведены к формату даты и превращены в индекс - поскольку все получаемые данные индексируются по дате и времени, это будет достаточно для обращения к определенным строкам.
#
# Поскольку данные за соседние промежутки времени схожи между собой, все пропуски в данных были заполнены значениями за ближайшее время.
#
# После анализа распределения данных в столбцах, было обнаружено наличие выбросов во многих параметрах в районе 0. Строки, содержащие значения, близкие к 0, были удалены.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ изменения концентрации элементов на различных этапах

# %% [markdown]
# Рассмотрим изменение концентрации элементов Au, Ag, Pb на каждом этапе.

# %%
au_concentrate = { 
    'rougher.input.feed_au': 'Сырье', 
    'rougher.output.concentrate_au' : 'Флотация', 
    'primary_cleaner.output.concentrate_au' : 'Первичная очистка',
    'final.output.concentrate_au' : 'Финальный концентрат'
}

ag_concentrate = {
    'rougher.input.feed_ag': 'Сырье', 
    'rougher.output.concentrate_ag' : 'Флотация', 
    'primary_cleaner.output.concentrate_ag' : 'Первичная очистка',
    'final.output.concentrate_ag' : 'Финальный концентрат'
}

pb_concentrate = {
    'rougher.input.feed_pb': 'Сырье', 
    'rougher.output.concentrate_pb' : 'Флотация', 
    'primary_cleaner.output.concentrate_pb' : 'Первичная очистка',
    'final.output.concentrate_pb' : 'Финальный концентрат'
}

def stages_concentration(element, stages):
    sns.set(style="darkgrid")
    for parameter, stage in stages.items():
        sns.histplot(
            data=data_full, 
            x=parameter,
            label=stage
        )
    plt.title(element)
    plt.xlabel('Концентрация')
    plt.legend() 
    plt.show()

# %%
stages_concentration('Золото', au_concentrate)

# %% [markdown]
# Как мы видим, на всех стадиях очистки, концентрация золота равномерно растет с каждой стадией, что логично, с учетом того, что это анализ данных золотодобывающей компании, и основным добывающимся полезным ископаемым является золото.

# %%
stages_concentration('Серебро', ag_concentrate)

# %% [markdown]
# Анализ распределения значений серебра показывает, что количество серебра уменьшается с каждой стадии очистки, при этом содержание серебра в исходном сырье не превышает значений на какой-либо из стадии, кроме финального концентрата. Это можно объяснить тем, что во время флотации в первую очередь порода очищается от пустой породы, поэтому после флотации концентрация серебра растет, и снижается лишь после первичной и вторичной очистки.

# %%
stages_concentration('Свинец', pb_concentrate)

# %% [markdown]
# Можно отметить, что распределение значений концентрации свинца сильно отличается от серебра и ближе к изменению распределений концентрации золота.
# В изначальном сырье концентрация свинца гораздо ниже, чем на остальных стадиях очистки, после флотации заметно повышается, а после первичной и вторичной очистки, наиболее частые значения концентраций схожи, меняются лишь края распределений. Это может быть связано с тем, что свинец при высоких температурах поглощает примеси, которые имеются у других металлов, из-за чего его концентрация растет. Другая возможная причина - сохранение свинца для последующей переработки с целью добычи дополнительного золота (в свинце может содержаться до 40% золота).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована концентрация металлов на разных стадиях обработки, проанализирована динамика концентрации в зависимости от этапа техпроцесса - отлично, тут всё верно.

# %% [markdown]
# ### Распределение размеров гранул исходного сырья

# %% [markdown]
# Перед тем, как начать обучение модели, сравним распределение гранул исходного сырья.

# %%
sns.set(style="darkgrid")
sns.histplot(
    data=data_train, 
    x='rougher.input.feed_size',
    label='Тренировочная выборка',
    stat='density'
    )
sns.histplot(
    data=data_test, 
    x='rougher.input.feed_size',
    label='Тестовая выборка',
    stat='density'
    )
plt.title('Распределение размеров гранул исходного сырья')
plt.xlabel('Размеры гранул исходного сырья')
plt.legend() 
plt.show()

# %% [markdown]
# Как мы видим по графику, размеры гранул в тренировочной и тестовой выборке идентичны, как и распределения.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Сравнили размеры гранул сырья на обучающей и тестовой выборках для этапа `rougher.input.feed_size` - отлично, распределения между выборками действительно схожи, следовательно модель будет корректно работать.
#
# Здорово, что используешь гистограмму плотности для оценки распределения непрерывных переменных.
#
# Чуть более интересным решением было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На графике не хватает названия.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %% [markdown]
# ### Суммарные концентрации металлов

# %% [markdown]
# Исследуем суммарную концентрацию металлов на разных стадиях: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате.
# Рассчитаем ее для каждой стадии и построим график распределения значений.

# %%
data_full['rougher.input.concentrate_sum'] =\
data_full['rougher.input.feed_au']  
+ data_full['rougher.input.feed_ag'] 
+ data_full['rougher.input.feed_pb']

data_full['rougher.output.concentrate_sum'] =\
data_full['rougher.output.concentrate_au'] 
+ data_full['rougher.output.concentrate_ag'] 
+ data_full['rougher.output.concentrate_pb']

data_full['primary_cleaner.output.concentrate_sum'] =\
data_full['primary_cleaner.output.concentrate_au']
+ data_full['primary_cleaner.output.concentrate_ag'] 
+ data_full['primary_cleaner.output.concentrate_pb']

data_full['final.output.concentrate_sum'] =\
data_full['final.output.concentrate_au']
+ data_full['final.output.concentrate_ag']
+ data_full['final.output.concentrate_pb']

sns.set(style="darkgrid")
for column in [
    'rougher.input.concentrate_sum', 
    'rougher.output.concentrate_sum', 
    'primary_cleaner.output.concentrate_sum', 
    'final.output.concentrate_sum'
]:
    sns.histplot(
    data=data_full, 
    x=column,
    label=column
    )
plt.title('Изменение суммарных концентраций металлов на различных стадиях')
plt.legend() 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> На графике не хватает названия.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %% [markdown]
# Как мы видим по графику, суммарная концентрация металлов растет с каждым уровнем очистки. При этом сами распределения практически идентичны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована суммарная концентрация металлов на разных стадиях техпроцесса - отлично!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Здесь заканчивается стрктурный блок работы - стоит сделать промежуточные выводы о проделанной работе в блоке.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %% [markdown]
# ### Выводы по этапу

# %% [markdown]
# В результате анализа данных были выявлены следующие закономерности:
# 1. Концентрация золота равномерно растет с каждой стадией очистки. Количество серебра уменьшается с каждой стадии очистки, при этом содержание серебра в исходном сырье не превышает значений на какой-либо из стадии, кроме финального концентрата. В изначальном сырье концентрация свинца гораздо ниже, чем на остальных стадиях очистки, после флотации заметно повышается, а после первичной и вторичной очистки, наиболее частые значения концентраций схожи, меняются лишь края распределений.
# 2. Плотности распределения размера гранул в обучающей и тестовой выборке практически идентично.
# 3. Суммарная концентрация металлов растет с каждым уровнем очистки. При этом сами распределения практически идентичны.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Создание оценочной метрики

# %% [markdown]
# Напишем функцию для определения оценочной метрики sMAPE

# %%
def calculate_smape(target, predictions):
    target_values = target.values if isinstance(target, pd.DataFrame) else target
    predictions_values = predictions.values if isinstance(predictions, pd.DataFrame) else predictions
    smape_rougher = (2 * np.abs(predictions[:, 0] - target_values[:, 0]) / (np.abs(predictions[:, 0]) + np.abs(target_values[:, 0]))) * 100
    smape_final = (2 * np.abs(predictions[:, 1] - target_values[:, 1]) / (np.abs(predictions[:, 1]) + np.abs(target_values[:, 1]))) * 100
    
    smape = 0.25 * np.mean(smape_rougher) + 0.75 * np.mean(smape_final)
    
    return smape

scorer = make_scorer(calculate_smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функции для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %% [markdown]
# ### Подготовка  данных для обучения

# %% [markdown]
# Для обучения и выбора лучшей модели, подготовим данные:
# - удалим из тренировочной выборки признаки, отсутствующие в тестовой
# - подготовим целевые признаки для тестовой выборки из исходных данных
# - смасштабируем признаки

# %%
features_train = data_train.drop(missing_columns, axis=1)
target_train = data_train[['rougher.output.recovery', 'final.output.recovery']]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Синхронизировали тренировочную и тестовую выборки по набору признаков - хорошо!
# </div>

# %%
features_test = data_test
target_test = data_full.loc[
    data_test.index][['rougher.output.recovery', 'final.output.recovery']]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В `test` добавили целевые признаки из `full`, используя дату как ключ при соединении - отлично!

# %%
scaler = StandardScaler()
scaler.fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнили масштабирование непрерывных признаков - отлично!
# </div>

# %% [markdown]
# ### Выбор наилучшей модели

# %% [markdown]
# Для сравнения возьмем следующие регрессионные модели:
# - линейная регрессия
# - модель решающего дерева
# - модель случайного леса
#
# Для всех этих моделей создадим словарь с гиперпараметрами, которые будем перебирать и сравнивать методом кросс-валидации.

# %%
lin_reg_model = LinearRegression(fit_intercept=True, positive=True)
tree_model = DecisionTreeRegressor(random_state=12345)
forest_model = RandomForestRegressor(random_state=12345)

# %%
lin_reg_params = {
}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Для линейной регрессии оптимизировать гиперпараметры не совсем корректно: так как её обучение сводится к решению системы линейных уравнений, то настройка гиперпараметров зависит от того, каким образом были подготовлены данные. Обратись, пожалуйста, к документации и выполни настройку гиперпараметров из сетки согласно описанию: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html.
#
# Сами гиперпараметры нужно настроить в момент инициализации модели.
#
# Можно просто оставить пустой словарь для линейной регрессии, и для неё будет просто выполнена кросс-валидация - так твоё решение не нужно будет сильно перестраивать.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %%
tree_model_params = {
    'criterion' : ['squared_error', 'absolute_error', 'poisson', 'friedman_mse'],
    'splitter' : ['best', 'random'],
    'max_depth' : [None] + [i for i in range(2, 7)],
    'min_samples_split' : range(2, 11, 5),
    'min_samples_leaf' : range(2,11,5),
    'max_features' : [1, 'sqrt', 'log2'],
    'max_leaf_nodes': range(2,15,5)
}

forest_model_params = {
    'n_estimators' : range(10,50,10),
    'criterion' : ['poisson', 'absolute_error', 'friedman_mse', 'squared_error'],
    'max_depth' : [None] + [i for i in range(2, 7)],
    'min_samples_split' : range(2, 11, 5),
    'min_samples_leaf' : range(1,11,5),
    'max_features' : [1, 'sqrt', 'log2']
}

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Для гиперпараметра `max_depth` рассматривается очень длинная последовательность: деревья с большой глубиной склонны к переобучению, а обучаются и предсказывают результат они дольше, поэтому делать их слишком глубокими не стоит - оптимальное значение почти всегда лежит в диапазоне от 2 до 5-6. Кроме того, можно попробовать значение `None` - в итоге оптимальная последовательность может выглядеть как `[None] + [i for i in range(2, 7)]`.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %%
best_lin_reg_model = RandomizedSearchCV(
    lin_reg_model,
    lin_reg_params,
    scoring=scorer,
    random_state=12345,
    n_iter=1
)

best_lin_reg_model.fit(features_train, target_train)
best_lin_reg_model.best_score_ * -1
# Out:
# 8.300002414321325

# %%
best_tree_model = RandomizedSearchCV(
    tree_model,
    tree_model_params,
    scoring=scorer,
    n_iter=50,
    n_jobs = -1,
    random_state=12345
)

best_tree_model.fit(features_train, target_train)
best_tree_model.best_score_ * -1
# Out:
# 8.675876486404901

# %%
best_forest_model = RandomizedSearchCV(
    forest_model,
    forest_model_params,
    n_iter=50,
    scoring=scorer,
    n_jobs=-1,
    random_state=12345
)

best_forest_model.fit(features_train, target_train)
best_forest_model.best_score_ * -1
# Out:
# 7.727954849032041

# %% [markdown]
# По результатам кроссвалидации, лучший результат показала модель решающего леса. Значение метрики sMAPE составило 7.73.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Также выбрана лучшая модель - порядок.

# %% [markdown]
# Проверим работу данной модели на тестовой выборке.

# %%
best_model = best_forest_model.best_estimator_
predictions = best_model.predict(features_test)

calculate_smape(target_test, predictions)
# Out:
# 6.2871307849188005

# %% [markdown]
# На тестовой выборке модель показала лучший результат, чем при кросс-валидации на тренировочной.
# Итоговое значение sMAPE составило 6.29.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
#
# <b>Ответ:</b> Исправил

# %% [markdown]
# ### Проверка модели на адекватность

# %% [markdown]
# Сравним результат, полученный лучшей моделью с константной моделью, всегда предсказывающей среднее значение в выборке.

# %%
dummy_model = DummyRegressor(strategy='mean')
dummy_model.n_outputs_=2
dummy_model.fit(features_train, target_train)

dummy_predictions = dummy_model.predict(features_test)

calculate_smape(target_test, dummy_predictions)
# Out:
# 8.343766413460102

# %% [markdown]
# По итогам проверки выбранной модели на адекватность, она показала лучший результат по сравнению с константной моделью, предсказывающей среднее значение тренировочных данных.
# Таким образом, можно судить об адекватности выбранной нами модели.

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе работы над проектом была выполнена следующая работа:
# 1. ***Проведена проверка расчета эффективности добычи сырья на этапе флотации.***
#     Средняя абсолютная ошибка между расчетной величиной и величиной в данных составила 9.83758577644259e-15
# 2. ***Проведено сравнение тренировочной и тестовой выборки**
#     В тестовой выборке отсутствуют значения параметров продукта после технологических операций, а так же расчетные характеристики после очистки.
# 3. ***Проведена предобработка данных***
#     Даты приведены к формату дат `pandas`. Поскольку все данные индексируются датой и временем, даты использованы как индекс. Пропуски обработаны путем заполнения из предыдущих значений, поскольку близкие по времени значения схожи. Околонулевые выбросы удалены.
# 4. ***Проведен анализ данных***
#    - **Анализ изменения концентрации металлов на разных ступенях очистки**
#        Концентрация золота равномерно растет с каждой стадией очистки. Количество серебра уменьшается с каждой стадии очистки, при этом содержание серебра в исходном сырье не превышает значений на какой-либо из стадии, кроме финального концентрата. В изначальном сырье концентрация свинца гораздо ниже, чем на остальных стадиях очистки, после флотации заметно повышается, а после первичной и вторичной очистки, наиболее частые значения концентраций схожи, меняются лишь края распределений.
#    - **Распределение размера гранул в обучающей и тестовой выборке**
#        Плотности распределения размера гранул в обучающей и тестовой выборке практически идентично.
#    - **Анализ распределения суммарных концентраций металлов после очистки**
#        Суммарная концентрация металлов растет с каждым уровнем очистки. При этом сами распределения практически идентичны.
# 5. ***Построена модель прогнозирования***
#    Три вида моделей (линейная регрессия, модель решающего дерева и модель случайного леса) с различными параметрами были обучены и сравнены методом кросс-валидации. Тренировочные и тестовые данные перед обучением были смасштабированы.
#
#    По результатам сравнения, лучшее значение метрики sMAPE было достигнуто моделью случайного леса и составило 7.78.
#
#    При проверке данной модели на тестовой выборке, было получено даже лучшее значение метрики sMAPE (**6.28**). После этого, модель была проверена на адекватность путем сравнения с константной моделью, предсказывающей среднее значение тестовой выборки. По результатам проверки выбранная модель признана адекватной.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Дмитрий, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец!
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"></h2>
# Еще раз спасибо большое за ревью! Было очень приятно прочитать и о правильности основных пунктов, и очень полезно изучть лайфхаки, а так же исправить замечания, о которых ты указал!
